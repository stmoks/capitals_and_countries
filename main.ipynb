# %%
import pandas as pd
import sqlite3
import re

# %% [markdown]
# ##### Scrape and load the Wiki data into a Pandas dataframe

# %%
url = 'https://en.wikipedia.org/wiki/List_of_national_capitals'
list_of_tables = pd.read_html(url)
capitals_df = list_of_tables[1]

# %% [markdown]
# ##### Clean the column names

# %%
capitals_df.rename(columns={'City/Town':'city'},inplace=True)
capitals_df.rename(columns={'Country/Territory':'country'},inplace=True)
capitals_df.rename(columns={'Notes':'notes'},inplace=True)

capitals_df['city_extra_info'] =  capitals_df['city'].apply(lambda x: x[len(re.search('^(.+?)\(',str(x)).group(1))+1:-1] if str(x).find('(') > 0 else '')
capitals_df['city'] = capitals_df['city'].apply(lambda x: re.search('^(.+?)\(',str(x)).group(1).strip() if str(x).find('(') > 0 else x)

# %%
capitals_df
# Out:
#              city                      country  \
# 0         Abidjan  Ivory Coast (Côte d'Ivoire)
# 1    Yamoussoukro  Ivory Coast (Côte d'Ivoire)
# 2       Abu Dhabi         United Arab Emirates
# 3           Abuja                      Nigeria
# 4           Accra                        Ghana
# ..            ...                          ...
# 255      Windhoek                      Namibia
# 256       Yaoundé                     Cameroon
# 257         Yaren                        Nauru
# 258       Yerevan                      Armenia
# 259        Zagreb                      Croatia
#
#                                                  notes  \
# 0    Abidjan is the largest city in Ivory Coast and...
# 1    Abidjan is the largest city in Ivory Coast and...
# 2                                                  NaN
# 3             Lagos was the capital from 1914 to 1991.
# 4                                                  NaN
# ..                                                 ...
# 255                                                NaN
# 256                                                NaN
# 257  Nauru has no official capital; however, the go...
# 258                                                NaN
# 259                                                NaN
#
#                                        city_extra_info
# 0    former capital; still hosts some government of...
# 1                                              de jure
# 2
# 3
# 4
# ..                                                 ...
# 255
# 256
# 257                                           de facto
# 258
# 259
#
# [260 rows x 4 columns]

# %%
capitals_df.to_csv('capitals.csv',header=True,index=False,encoding='utf-16')
capitals_csv = pd.read_csv('capitals.csv',encoding='utf-16')

# %% [markdown]
# ##### Create a SQL Lite database

# %%
conn = sqlite3.connect('capitals.db')
cc_cursor = sqlite3.Cursor(conn)

# %%
drop_table = 'DROP TABLE IF EXISTS capitals'

# %%
cc_cursor.execute(drop_table)

# %%
create_table = '''CREATE TABLE capitals (
                    city VARCHAR(250),
                    city_extra_info VARCHAR(250),
                    country VARCHAR(250),
                    notes VARCHAR(500)
)'''

# %%
cc_cursor.execute(create_table)

# %%
capitals_csv.to_sql('capitals',conn,if_exists='append',index=False)
# Out:
# 260

# %%
view_snapshot = pd.read_sql('SELECT * FROM capitals LIMIT 20',conn)

# %%
view_snapshot
# Out:
#                 city                                    city_extra_info  \
# 0            Abidjan  former capital; still hosts some government of...
# 1       Yamoussoukro                                            de jure
# 2          Abu Dhabi                                               None
# 3              Abuja                                               None
# 4              Accra                                               None
# 5          Adamstown                                               None
# 6        Addis Ababa                                               None
# 7               Aden                                de facto, temporary
# 8              Sanaa                                            de jure
# 9            Algiers                                               None
# 10             Alofi                                               None
# 11             Amman                                               None
# 12         Amsterdam                                           official
# 13         The Hague                                           de facto
# 14  Andorra la Vella                                               None
# 15            Ankara                                               None
# 16      Antananarivo                                               None
# 17              Apia                                               None
# 18          Ashgabat                                               None
# 19            Asmara                                               None
#
#                         country  \
# 0   Ivory Coast (Côte d'Ivoire)
# 1   Ivory Coast (Côte d'Ivoire)
# 2          United Arab Emirates
# 3                       Nigeria
# 4                         Ghana
# 5              Pitcairn Islands
# 6                      Ethiopia
# 7                         Yemen
# 8                         Yemen
# 9                       Algeria
# 10                         Niue
# 11                       Jordan
# 12                  Netherlands
# 13                  Netherlands
# 14                      Andorra
# 15                       Turkey
# 16                   Madagascar
# 17                        Samoa
# 18                 Turkmenistan
# 19                      Eritrea
#
#                                                 notes
# 0   Abidjan is the largest city in Ivory Coast and...
# 1   Abidjan is the largest city in Ivory Coast and...
# 2                                                None
# 3            Lagos was the capital from 1914 to 1991.
# 4                                                None
# 5                         British Overseas Territory.
# 6                                                None
# 7   Due to the Yemeni civil war (2014–present), Sa...
# 8   Due to the Yemeni civil war (2014–present), Sa...
# 9                                                None
# 10  Self-governing in free association with New Ze...
# 11                                               None
# 12  The Dutch government is located in The Hague, ...
# 13  The Dutch government is located in The Hague, ...
# 14                                               None
# 15  Ankara became the capital of the newly-formed ...
# 16                                               None
# 17                                               None
# 18                                               None
# 19                                               None

# %%
more_than_2_capitals = pd.read_sql( '''SELECT country,city,city_extra_info FROM capitals
                                    WHERE country IN (SELECT country
                                                    FROM capitals 
                                                    GROUP BY country
                                                    HAVING count(*) > 1)
                          ''',conn)

# %%
more_than_2_capitals
# Out:
#                            country                       city  \
# 0      Ivory Coast (Côte d'Ivoire)                    Abidjan
# 1      Ivory Coast (Côte d'Ivoire)               Yamoussoukro
# 2                            Yemen                       Aden
# 3                            Yemen                      Sanaa
# 4                      Netherlands                  Amsterdam
# 5                      Netherlands                  The Hague
# 6                     South Africa               Bloemfontein
# 7                     South Africa                  Cape Town
# 8                     South Africa                   Pretoria
# 9                       Montserrat                     Brades
# 10                      Montserrat                   Plymouth
# 11                       Sri Lanka                    Colombo
# 12                       Sri Lanka  Sri Jayawardenepura Kotte
# 13                           Benin                    Cotonou
# 14                           Benin                 Porto-Novo
# 15                         Burundi                     Gitega
# 16                         Burundi                  Bujumbura
# 17                       Palestine                  Jerusalem
# 18                       Palestine                   Ramallah
# 19                        Malaysia               Kuala Lumpur
# 20                        Malaysia                  Putrajaya
# 21                         Bolivia                     La Paz
# 22                         Bolivia                      Sucre
# 23                  Western Sahara                   Laayoune
# 24                  Western Sahara                   Tifariti
# 25                        Eswatini                    Lobamba
# 26                        Eswatini                    Mbabane
# 27  British Indian Ocean Territory                     London
# 28  British Indian Ocean Territory               Diego Garcia
# 29                        Honduras                Tegucigalpa
# 30                        Honduras                Comayagüela
#
#                                       city_extra_info
# 0   former capital; still hosts some government of...
# 1                                             de jure
# 2                                 de facto, temporary
# 3                                             de jure
# 4                                            official
# 5                                            de facto
# 6                                            judicial
# 7                                         legislative
# 8                                           executive
# 9                                            de facto
# 10                                            de jure
# 11                                executive, judicial
# 12                                           official
# 13                                           de facto
# 14                                           official
# 15                                            de jure
# 16                                           de facto
# 17                                               None
# 18                                           de facto
# 19                     de jure, legislative and royal
# 20                        administrative and judicial
# 21                                     administrative
# 22                                     constitutional
# 23                                           declared
# 24                                           de facto
# 25                              royal and legislative
# 26                                     administrative
# 27                                     administration
# 28                                           de facto
# 29                                               None
# 30                                               None

# %%
conn.close()
