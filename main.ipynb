# %%
import pandas as pd
import sqlite3
import re
import unidecode

# %% [markdown]
# ##### Scrape and load the Wiki data into a Pandas dataframe

# %%
capitals_url = 'https://en.wikipedia.org/wiki/List_of_national_capitals'
list_of_tables = pd.read_html(capitals_url)
capitals_df = list_of_tables[1]

cities_url = 'https://en.wikipedia.org/wiki/List_of_cities_by_elevation'
list_of_tables = pd.read_html(cities_url)
cities_df = list_of_tables[1]

# %%
capitals_df
# Out:
#                                              City/Town  \
# 0    Abidjan (former capital; still hosts some gove...
# 1                               Yamoussoukro (de jure)
# 2                                            Abu Dhabi
# 3                                                Abuja
# 4                                                Accra
# ..                                                 ...
# 255                                           Windhoek
# 256                                            Yaoundé
# 257                                   Yaren (de facto)
# 258                                            Yerevan
# 259                                             Zagreb
#
#                Country/Territory  \
# 0    Ivory Coast (Côte d'Ivoire)
# 1    Ivory Coast (Côte d'Ivoire)
# 2           United Arab Emirates
# 3                        Nigeria
# 4                          Ghana
# ..                           ...
# 255                      Namibia
# 256                     Cameroon
# 257                        Nauru
# 258                      Armenia
# 259                      Croatia
#
#                                                  Notes
# 0    Abidjan is the largest city in Ivory Coast and...
# 1    Abidjan is the largest city in Ivory Coast and...
# 2                                                  NaN
# 3             Lagos was the capital from 1914 to 1991.
# 4                                                  NaN
# ..                                                 ...
# 255                                                NaN
# 256                                                NaN
# 257  Nauru has no official capital; however, the go...
# 258                                                NaN
# 259                                                NaN
#
# [260 rows x 3 columns]

# %% [markdown]
# ##### Clean the column names

# %%
capitals_df.rename(columns={'City/Town':'city'},inplace=True)
capitals_df.rename(columns={'Country/Territory':'country'},inplace=True)
capitals_df.rename(columns={'Notes':'notes'},inplace=True)

# extract all the data before the extra information
capitals_df['city'] = capitals_df['city'].apply(lambda x: re.search('^(.+?)\(',str(x)).group(1).strip() if str(x).find('(') > 0 else x)
capitals_df['country'] = capitals_df['country'].apply(lambda x: re.search('^(.+?)\[',str(x)).group(1).strip() if str(x).find('[') > 0 else x)

# add the extra information to a new column
capitals_df['city_extra_info'] =  capitals_df['city'].apply(lambda x: x[len(re.search('^(.+?)\(',str(x)).group(1))+1:-1] if str(x).find('(') > 0 else '')

# remove special characters from the city and country names so we can join two datasets later
capitals_df['city'] = capitals_df['city'].apply(lambda x:re.sub('[\',.]','',x).strip())
capitals_df['country'] = capitals_df['country'].apply(lambda x:re.sub('[\',.]','',x).strip())

# convert the city and country to a standard unicode format
capitals_df['city'] = capitals_df['city'].apply(lambda x:unidecode.unidecode(x).strip())
capitals_df['country'] = capitals_df['country'].apply(lambda x:unidecode.unidecode(x).strip())

# %%
cities_df.rename(columns={'City Name/s':'city'},inplace=True)
cities_df.rename(columns={'Country/Territory':'country'},inplace=True)
cities_df.rename(columns={'Continental Region':'continent'},inplace=True)
cities_df.rename(columns={'Population':'population'},inplace=True)
cities_df.rename(columns={'Latitude':'latitude'},inplace=True)
cities_df.rename(columns={'Longitude':'longitude'},inplace=True)
cities_df.rename(columns={'Elevation (m)':'elevation'},inplace=True)

# extract all the data before the extra information
cities_df['elevation'] = cities_df['elevation'].apply(lambda x: re.search('^(.+?)\[',str(x)).group(1).strip() if str(x).find('[') > 0 else x)
cities_df['country'] = cities_df['country'].apply(lambda x: re.search('^(.+?)\[',str(x)).group(1).strip() if str(x).find('[') > 0 else x)
cities_df['city'] = cities_df['city'].apply(lambda x: re.search('^(.+?)\[',str(x)).group(1).strip() if str(x).find('[') > 0 else x)

# remove special characters from the city and country names so we can join two datasets later
cities_df['city'] = cities_df['city'].apply(lambda x:re.sub('[\',.]','',x).strip())
cities_df['country'] = cities_df['country'].apply(lambda x:re.sub('[\',.]','',x).strip())

# convert the city and country to a standard unicode format
cities_df['city'] = cities_df['city'].apply(lambda x:unidecode.unidecode(x).strip())
cities_df['country'] = cities_df['country'].apply(lambda x:unidecode.unidecode(x).strip())

# %%
cities_df
# Out:
#               country              city continent    latitude    longitude  \
# 0               Nepal           Pokhara      Asia    N28.2096     E83.9856
# 1        South Africa      Bloemfontein    Africa  S29.116667  E026.216667
# 2               China          Shanghai      Asia    N31.2304    E121.4737
# 3               Italy             Milan    Europe    N45.4625    E9.186389
# 4          Kazakhstan          Pavlodar      Asia    N52.3000   E76.950000
# ..                ...               ...       ...         ...          ...
# 189         Australia          Brisbane   Oceania    S27.4710    E153.0242
# 190         Australia          Adelaide   Oceania    S34.9286    E138.5986
# 191       New Zealand        Wellington   Oceania    S41.2865    E174.7762
# 192  Papua New Guinea      Port Moresby   Oceania    S09.4656    E147.1969
# 193           Vietnam  Ho Chi Minh City      Asia    N10.8231    E106.6297
#
#      population elevation
# 0      523000.0       822
# 1      747431.0      1395
# 2    26320000.0       122
# 3     1378689.0       122
# 4      353930.0       123
# ..          ...       ...
# 189         NaN        28
# 190         NaN        61
# 191         NaN        20
# 192         NaN        39
# 193   8637000.0        19
#
# [194 rows x 7 columns]

# %% [markdown]
# ##### Join the two datasets

# %%
# join so we can use geo pandas
capitals_with_coordinates = pd.merge(capitals_df,cities_df,how='left',on = ['city','country'])

# %%
capitals_with_coordinates
# Out:
#              city                     country  \
# 0         Abidjan  Ivory Coast (Cote dIvoire)
# 1    Yamoussoukro  Ivory Coast (Cote dIvoire)
# 2       Abu Dhabi        United Arab Emirates
# 3           Abuja                     Nigeria
# 4           Accra                       Ghana
# ..            ...                         ...
# 255      Windhoek                     Namibia
# 256       Yaounde                    Cameroon
# 257         Yaren                       Nauru
# 258       Yerevan                     Armenia
# 259        Zagreb                     Croatia
#
#                                                  notes city_extra_info  \
# 0    Abidjan is the largest city in Ivory Coast and...
# 1    Abidjan is the largest city in Ivory Coast and...
# 2                                                  NaN
# 3             Lagos was the capital from 1914 to 1991.
# 4                                                  NaN
# ..                                                 ...             ...
# 255                                                NaN
# 256                                                NaN
# 257  Nauru has no official capital; however, the go...
# 258                                                NaN
# 259                                                NaN
#
#     continent  latitude  longitude  population elevation
# 0         NaN       NaN        NaN         NaN       NaN
# 1         NaN       NaN        NaN         NaN       NaN
# 2        Asia  N24.4764  E054.3705         NaN        13
# 3      Africa  N09.0580  E007.4891         NaN       777
# 4      Africa  N05.5401  W000.2074         NaN        98
# ..        ...       ...        ...         ...       ...
# 255    Africa  S22.5749  E017.0805    325858.0      1655
# 256    Africa  N03.8612  E011.5217         NaN       726
# 257       NaN       NaN        NaN         NaN       NaN
# 258      Asia  N40.1596  E044.5090         NaN      1032
# 259    Europe  N45.8150  E015.9785    792324.0       130
#
# [260 rows x 9 columns]

# %% [markdown]
# ##### Quality Assurance

# %%
#TODO Clean up the the city and country more so we can better join, include city/country with accents column
issues = capitals_with_coordinates[(capitals_with_coordinates['population'].isna()) & (capitals_with_coordinates['continent'].isna())]
issues.to_csv('issues.csv',encoding='utf-16',index=False)

# %%
capitals_with_coordinates.to_csv('capitals.csv',header=True,index=False,encoding='utf-16')
capitals_csv = pd.read_csv('capitals.csv',encoding='utf-16')

# %% [markdown]
# ##### Create a SQL Lite database

# %%
conn = sqlite3.connect('capitals.db')
cc_cursor = sqlite3.Cursor(conn)

# %%
drop_table = 'DROP TABLE IF EXISTS capitals'

# %%
cc_cursor.execute(drop_table)

# %%
create_table = '''CREATE TABLE capitals (
                    city VARCHAR(250),
                    city_extra_info VARCHAR(250),
                    country VARCHAR(250),
                    notes VARCHAR(500),
                    continent VARCHAR(20),
                    latitude VARCHAR(30),
                    longitude VARCHAR(30),
                    population NUMERIC(15),
                    elevation NUMERIC(10)
            
)'''

# %%
cc_cursor.execute(create_table)

# %%
capitals_csv.to_sql('capitals',conn,if_exists='append',index=False)
# Out:
# 260

# %%
view_snapshot = pd.read_sql('SELECT * FROM capitals LIMIT 20',conn)

# %%
view_snapshot
# Out:
#                 city city_extra_info                     country  \
# 0            Abidjan            None  Ivory Coast (Cote dIvoire)
# 1       Yamoussoukro            None  Ivory Coast (Cote dIvoire)
# 2          Abu Dhabi            None        United Arab Emirates
# 3              Abuja            None                     Nigeria
# 4              Accra            None                       Ghana
# 5          Adamstown            None            Pitcairn Islands
# 6        Addis Ababa            None                    Ethiopia
# 7               Aden            None                       Yemen
# 8              Sanaa            None                       Yemen
# 9            Algiers            None                     Algeria
# 10             Alofi            None                        Niue
# 11             Amman            None                      Jordan
# 12         Amsterdam            None                 Netherlands
# 13         The Hague            None                 Netherlands
# 14  Andorra la Vella            None                     Andorra
# 15            Ankara            None                      Turkey
# 16      Antananarivo            None                  Madagascar
# 17              Apia            None                       Samoa
# 18          Ashgabat            None                Turkmenistan
# 19            Asmara            None                     Eritrea
#
#                                                 notes continent  latitude  \
# 0   Abidjan is the largest city in Ivory Coast and...      None      None
# 1   Abidjan is the largest city in Ivory Coast and...      None      None
# 2                                                None      Asia  N24.4764
# 3            Lagos was the capital from 1914 to 1991.    Africa  N09.0580
# 4                                                None    Africa  N05.5401
# 5                         British Overseas Territory.      None      None
# 6                                                None    Africa  N09.0084
# 7   Due to the Yemeni civil war (2014–present), Sa...      None      None
# 8   Due to the Yemeni civil war (2014–present), Sa...      Asia  N15.3556
# 9                                                None      None      None
# 10  Self-governing in free association with New Ze...      None      None
# 11                                               None      Asia    N34.11
# 12  The Dutch government is located in The Hague, ...    Europe  N52.3738
# 13  The Dutch government is located in The Hague, ...      None      None
# 14                                               None      None      None
# 15  Ankara became the capital of the newly-formed ...      Asia  N39.9439
# 16                                               None    Africa  S18.9201
# 17                                               None      None      None
# 18                                               None      Asia  N37.9509
# 19                                               None    Africa  N15.3315
#
#     longitude  population  elevation
# 0        None         NaN        NaN
# 1        None         NaN        NaN
# 2   E054.3705         NaN       13.0
# 3   E007.4891         NaN      777.0
# 4   W000.2074         NaN       98.0
# 5        None         NaN        NaN
# 6   E038.7575   3384569.0     2362.0
# 7        None         NaN        NaN
# 8   E044.2081   1937451.0     2253.0
# 9        None         NaN        NaN
# 10       None         NaN        NaN
# 11    E021.41         NaN     1094.0
# 12  E004.8910         NaN       -2.0
# 13       None         NaN        NaN
# 14       None         NaN        NaN
# 15  E032.8560         NaN      938.0
# 16  E047.5237         NaN     1288.0
# 17       None         NaN        NaN
# 18  E058.3794         NaN      215.0
# 19  E038.9183    649000.0     2363.0

# %% [markdown]
# ##### Countries with more than 2 capitals

# %%
more_than_2_capitals = pd.read_sql( '''SELECT country,city FROM capitals
                                    WHERE country IN (SELECT country
                                                    FROM capitals 
                                                    GROUP BY country
                                                    HAVING count(*) > 1)
                          ''',conn)

# %%
more_than_2_capitals
# Out:
#                            country                       city
# 0       Ivory Coast (Cote dIvoire)                    Abidjan
# 1       Ivory Coast (Cote dIvoire)               Yamoussoukro
# 2                            Yemen                       Aden
# 3                            Yemen                      Sanaa
# 4                      Netherlands                  Amsterdam
# 5                      Netherlands                  The Hague
# 6                     South Africa               Bloemfontein
# 7                     South Africa                  Cape Town
# 8                     South Africa                   Pretoria
# 9                       Montserrat                     Brades
# 10                      Montserrat                   Plymouth
# 11                       Sri Lanka                    Colombo
# 12                       Sri Lanka  Sri Jayawardenepura Kotte
# 13                           Benin                    Cotonou
# 14                           Benin                 Porto-Novo
# 15                         Burundi                     Gitega
# 16                         Burundi                  Bujumbura
# 17                       Palestine                  Jerusalem
# 18                       Palestine                   Ramallah
# 19                        Malaysia               Kuala Lumpur
# 20                        Malaysia                  Putrajaya
# 21                         Bolivia                     La Paz
# 22                         Bolivia                      Sucre
# 23                  Western Sahara                   Laayoune
# 24                  Western Sahara                   Tifariti
# 25                        Eswatini                    Lobamba
# 26                        Eswatini                    Mbabane
# 27  British Indian Ocean Territory                     London
# 28  British Indian Ocean Territory               Diego Garcia
# 29                        Honduras                Tegucigalpa
# 30                        Honduras                Comayaguela

# %% [markdown]
# ##### Top 5 cities by elevation

# %%
top_5_elevation = pd.read_sql('''SELECT * FROM 
                              (SELECT *,RANK() OVER(ORDER BY elevation DESC) AS ranker
                              FROM capitals
                              )
                              WHERE ranker < 6

''',conn)

# %%
top_5_elevation
# Out:
#           city city_extra_info   country  \
# 0       La Paz            None   Bolivia
# 1        Quito            None   Ecuador
# 2       Bogota            None  Colombia
# 3       Asmara            None   Eritrea
# 4  Addis Ababa            None  Ethiopia
#
#                                                notes continent  latitude  \
# 0  La Paz is the highest administrative capital (...  Americas   -16.500
# 1             Highest official capital (2,850 m).[5]  Americas  S00.2295
# 2                                               None  Americas  N04.6473
# 3                                               None    Africa  N15.3315
# 4                                               None    Africa  N09.0084
#
#    longitude  population  elevation  ranker
# 0    -68.150      877363       3812       1
# 1  W078.5243     2671191       2850       2
# 2  W074.0962     7878783       2619       3
# 3  E038.9183      649000       2363       4
# 4  E038.7575     3384569       2362       5

# %% [markdown]
# ##### Most populous capital in each continent

# %%
most_populous_continent = pd.read_sql('''SELECT city,country,continent,population FROM 
                              (SELECT *,RANK() OVER(PARTITION BY continent ORDER BY population DESC) AS ranker
                              FROM capitals
                              WHERE population IS NOT NULL AND population IS NOT NULL
                              )
                              WHERE ranker = 1

''',conn)

# %%
most_populous_continent
# Out:
#           city      country continent  population
# 0  Addis Ababa     Ethiopia    Africa     3384569
# 1  Mexico City       Mexico  Americas     8918653
# 2       Manila  Philippines      Asia    12877253
# 3        Minsk      Belarus    Europe     1982444

# %%
# conn.close()
